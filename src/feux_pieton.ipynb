# %%
import pandas as pd
import plotly.express as px
# Out:
# /var/folders/66/lykx91p150q4wl3w7w5ypwdh0000gn/T/ipykernel_87684/2165325793.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("../data/feux-pietons.csv")
df
# Out:
#       INT_NO                     RUE_1                  RUE_2  \
# 0        191                 Van Horne                   Vimy
# 1        192                 Van Horne               Westbury
# 2        193                 Van Horne              Wilderton
# 3        194                    Vézina               Victoria
# 4        195                  Crémazie         Michel-Jurdant
# ...      ...                       ...                    ...
# 2103   19152                 Cavendish      Thimens Int Ouest
# 2104   19153       Émile-Nelligan Nord             Laurentien
# 2105   19155                 Cavendish   Côte-Vertu Int Ouest
# 2106   19169  Crémazie Est inter. Nord              Accès ORA
# 2107   19182         1460 Crémazie Est  Crémazie Est .Int Sud
#
#       NO_ARRONDISSEMENT                            ARRONDISSEMENT  \
# 0                     7     Côte-des-Neiges - Notre-Dame-de-Grâce
# 1                     7     Côte-des-Neiges - Notre-Dame-de-Grâce
# ...
